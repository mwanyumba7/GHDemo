# %% [markdown]
# # Data Visualization in Excel
#
# ## Goals for This Section
#
# - Understand the **three key questions** for choosing the most effective visuals
# - Introduce essential chart types: **line charts, bar charts, scatter plots, and maps**
# - Review chart formatting tips to **eliminate noise, improve clarity**, and **facilitate understanding**
# - Address **common data visualization mistakes** — and how to avoid them
#
# ## Why Visualize Data?
#
# > **The 10-Second Rule**
# In just 10 seconds, what can you learn from a dataset?
# Good visualizations should answer this question **clearly and quickly.**
#
# ## The Essential Questions
#
# When selecting a chart type, always ask yourself:
#
# 1. **What is the main message I want to communicate?**
# 2. **What type of data am I working with?** (categorical, time series, distribution, etc.)
# 3. **Which chart type will communicate the story most clearly?**
#
# ## Essential Chart Types
#
# Visualizing data is a key part of effective analysis, and Excel offers a wide range of tools to help you present information clearly.
#
# Understanding the different types of charts in Excel can help you choose the best way to display your data based on your goals and audience.
#
# From simple visuals like **bar charts** and **pie charts** to more advanced options such as **scatter plots**, **histograms**, and **combo charts**, each chart type serves a specific purpose in data storytelling.
#
# ### Different Chart Types in Excel
# There are various charts available in excel. Namely, they are:
#
# - **Line Charts**
# - **Bar Charts**
# - **Scatter Plots**
# - **Bubble Chart**
# - **Maps**
# - **Column Chart**
# - **Area Chart**
# - **Pie Chart**
# - **Surface Chart**
#
# In this example, we will be using random car sales data, including model name and the number of cars sold, as the dataset and represent it in the various graphs.
#
# ### Create dataset
# In this step, we will be inserting random financial sales data into our excel sheet. Below is the screenshot of the random data we will use for our various graphs.
#
# ![image.png](attachment:image.png)
#
# #### Line Chart
#
# Line charts are most helpful in representing the trends. This can be very useful to analyze the ups and downs in a range of data over a particular time span. The data points in the chart are connected with the lines.
#
# **Note**: To insert the graph, we need to select our dataset(or data table) and go to insert and then in the chart section and insert whatever graph we want.
#
# ![image-2.png](attachment:image-2.png)
#
# #### Bar Chart
#
# Bar charts are used to represent the categorical data using the rectangular horizontal bars with their height and length proportional to the data values it is used to represent.
#
# ![image-3.png](attachment:image-3.png)
#
# #### Column Chart
#
# Column charts are used to represent the data in a vertical chart using the vertical bars. These graphs are mostly used for comparing the data points in the data. Column chart
#
# ![image-4.png](attachment:image-4.png)
#
# #### Area Chart
#
# Area charts are used to display graphically quantitative data. It is similar to the line chart and based on it. The area between the lines is filled with color, and they are easy to analyze as they are similar to the line chart showing ups and downs in the data.
#
# ![image-5.png](attachment:image-5.png)
#
# #### Pie Chart
#
# Pie charts are circular statistical graphs that are divided into slices of pie in the proportion to data values to represent the data. They are commonly used to analyze the percentage allocation of data points incomplete dataset.
#
# ![image-6.png](attachment:image-6.png)
#
#
# ### Scatter and Bubble Chart Visualization in Excel
#
# - Scatter Charts and Bubble Charts display many related data in one Chart.
# - In both of these charts, the X - axis displays one numeric field and the Y-axis displays another.
# - It helps to specify the relationship between two values for all the items in the chart easily.
# - In Bubble charts, a third numeric field controls the size of the data points.
#
# #### Scatter Chart Visualization
#
# - A **scatter chart** always displays two value axes: one set of numerical data along the horizontal axis and another set of numerical values along the vertical axis.
#
# #### How to Create a Scatter Chart in Excel
#
# **Step 1**: Make a table with only one category value. Select the **Months**, **Sales**, and **Quarter fields**. The **Month** is a category field, whereas **Sales** and **Quarter** are numeric fields.
#
# ![image-7.png](attachment:image-7.png)
#
# **Step 2**: Select the **Table**. Navigate to the **DESIGN** tab. In the Switch Visualization group, choose **Other Chart**. Choose **Scatter** from the dropdown menu.
#
# ![image-8.png](attachment:image-8.png)
#
# **Step 3**: The table will be transformed into a **scatter chart**. The data points are shown as circles of the same size, demonstrating how the Quarter and sales figures for each sport are connected. The **X-Axis** represents the quarter, while the **Y-Axis** represents sales.
#
# ![image-9.png](attachment:image-9.png)
#
# **Step 4:** In the Power View Fields pane, the **quarter** is under area - **X VALUE**. In the Power View Fields pane, the **sales** are under area - **Y VALUE**. In the Power View Fields pane, the **Months** are under the area - **DETAILS**.
#
# ![image-12.png](attachment:image-12.png)
#
# #### Bubble Chart Visualization in Excel
#
# - A **bubble chart**, an extension of a Scatter plot, is widely used to depict correlations between three or more numerical variables.
# - A single data point is represented by each bubble in a chart.
# - Each bubble's value is represented by :
#     1. Its horizontal location on the x-axis
#     2. Its vertical position on the y-axis
#     3. Its size.
# - The color of the bubble or its movement in animation can sometimes symbolize additional dimensions.
#
# #### How to Create a Bubble Chart in Excel
#
# **Step 1: Open Sheet and Select the Data**
#
# Go to the Excel sheet in which you want to insert the Bubble Chart and Select the required Data Set.
#
# ![image-10.png](attachment:image-10.png)
#
# **Step 2: Find the Insert Tab and Select Charts**
#
# Click on Insert Tab and under Charts Section Click on Bubble Chart from the Drop down.
#
# ![image-11.png](attachment:image-11.png)
#
# #### How to Convert Scatter Chart Visualization into Bubble Chart Visualization
#
# **Step 1:** Drag the **Percentage of Sales** field from the active fields to the ∑ **Size area**. The **Scatter chart** will be replaced by a **Bubble chart**.
#
# ![image-13.png](attachment:image-13.png)
#
# **Step 2**: The table will be transformed into a Bubble chart. The **X-Axis** represents the **quarter**, while the **Y-Axis** represents **sales**. The **size** of each bubble represents the **percentage of sales**. The **Month** is displayed in the **Data Labels**.
#
# ![image-14.png](attachment:image-14.png)
#
#
# ## Chart Formatting Tips
#
# - **Eliminate clutter:** Remove unnecessary gridlines, borders, and 3D effects
# - **Use color sparingly:** Emphasize key points only
# - **Label clearly:** Use descriptive titles, axis labels, and data labels
# - **Avoid chartjunk:** Focus on clarity, not decoration
#
# ## Common Visualization Mistakes
#
# - Using **inappropriate chart types** (e.g., pie charts for too many categories)
# - Overusing **colors or effects** that distract
# - **Lack of context** (missing titles, axis labels, or legends)
# - Ignoring **data integrity** (e.g., inconsistent scales)
#
# ## Tools & Features in Excel
#
# ### Calculated Values and Fields
#
# Pivot Tables allow you to add **calculated fields** and **custom measures** for advanced summaries.
#
# ### Pivot Charts
#
# - Dynamic charts tied to pivot tables
# - Easy to filter and break down categories using **slicers**
#
# **Watch:** [Using Slicers in Excel](https://youtu.be/7K_KqD1S2M0?si=iKshNv8fzFhD-hid)
#
# ## Resources
#
# - [Data Storytelling Principles by Chris Aloo](#)
# - [Beginners Guide to Excel Dashboards](https://youtu.be/s0E2pmXQcPA?si=uSG7Tjy25G7XSOhM)
# - [Intermediate Guide to Dashboards](https://youtu.be/thmQ63nTn84?si=isRMJ_1of-zQVXo6)
